# %%
print("Hello World")
# Out:
# Hello World

# %%
s=3
t=12
s*t
# Out:
# 36

# %%
import numpy
import pandas

# %%
# %matplotlib inline
import matplotlib.pylab as plt

# %%
plt.plot([3,5,8],[2,5,7])

# %%
plt.scatter([3,5,8],[2,5,7])

# %%
i=0
while i<100:
    print("infinite loop")
# Out:
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# ...

# %% [markdown]
# # Markdown Text Practice
# This is a text cell

# %%
# ?plt

# %%
# ?plt.rand

# %%
plt.rand(6,4)
# Out:
# array([[ 0.55997555,  0.08406586,  0.15766907,  0.05094008],
#        [ 0.41146951,  0.12366727,  0.27554028,  0.65537334],
#        [ 0.29761846,  0.47687639,  0.23740537,  0.41005509],
#        [ 0.90026327,  0.0991346 ,  0.85895827,  0.14964398],
#        [ 0.26148929,  0.02312808,  0.31666854,  0.96458871],
#        [ 0.14969131,  0.77457056,  0.62931788,  0.60634327]])

# %%
plt.plot(plt.rand(6,4))
